# %%
import pandas as pd

# %%
df = pd.Series([1,2,3])

# %%
dados = ({
    'nome':['nar','pe'],
    'idade': [1, 3]
})

df = pd.DataFrame(dados)

# %%
df.head(4)
df.info()
df.describe()
df.dtypes

# %%
df = pd.read_csv('GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
dados = ({
    'nome':['nar','pe'],
    'idade': [1, 3]
})

df = pd.DataFrame(dados)
df.to_excel('dados.xlsx', index=False)

# %%
df['nome']

# %%
df.loc[0]
df.iloc[0]

# %%
selecao = df['nome'] == 'nart'
selecao

# %%
df.loc[df['idade'] > 18, ['nome']]

# %%
for index, row in df.iterrows():
    print(row['nome'])

# %%
df.loc[df['nome'].isin(['pe', 'kamikoshi'])]

# %%
from datetime import datetime

hoje  = datetime.now()

data = '19/02/2023'
data = datetime.strptime(data, '%d/%m/%Y')
print(data)
